# %% [markdown]
# # Start digging into your data and generating visualizations to spot strange patterns or interesting statistics.

# %% [markdown]
# ## Think of questions that data can answer. For example:
# - Can you see which senator declared the most expenses?
# - What percentage of the quota did the senators spend?
# - Did you have any with more than 90%?
# - In an election year, do senators spend more?

# %% [markdown]
# # Load libraries

# %%
import pandas as pd
import numpy as np
import plotly.offline as py
import plotly.graph_objs as go

py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Load the dataset

# %%
dataset = pd.read_csv('../day1/datasets/dataset_preprocessed.csv', sep=';')
dataset
# Out:
#         ANO  MES           SENADOR  \
# 0      2019    1      ACIR GURGACZ
# 1      2019    1      ACIR GURGACZ
# 2      2019    1      ACIR GURGACZ
# 3      2019    1      ACIR GURGACZ
# 4      2019    2      ACIR GURGACZ
# ...     ...  ...               ...
# 52527  2021   12  ZEQUINHA MARINHO
# 52528  2021   12  ZEQUINHA MARINHO
# 52529  2021   12  ZEQUINHA MARINHO
# 52530  2021   12  ZEQUINHA MARINHO
# 52531  2021   12  ZEQUINHA MARINHO
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 0      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2      Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3      Aluguel de imóveis para escritório político, c...  05.423.963/0001-11
# 4      Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# ...                                                  ...                 ...
# 52527  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 52528  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 52529  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 52530  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 52531  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
#
#                           FORNECEDOR        DATA  VALOR_REEMBOLSADO  \
# 0                           ENERGISA  2019-04-01              66.02
# 1                           ENERGISA  2019-04-01             139.98
# 2      GILBERTO PISELO DO NASCIMENTO  2019-07-01            6000.00
# 3                      OI MÓVEL S.A.  2018-12-25             316.39
# 4                           ENERGISA  2019-04-02              99.45
# ...                              ...         ...                ...
# 52527                  Exceller Tour  2021-01-12            1715.45
# 52528                  Exceller Tour  2021-12-15            2489.29
# 52529                  Exceller Tour  2021-12-17            1486.66
# 52530                  Exceller Tour  2021-12-27            2515.56
# 52531                  Exceller Tour  2021-12-29            1510.75
#
#        COD_DOCUMENTO
# 0            2116543
# 1            2116546
# 2            2113817
# 3            2116541
# 4            2116550
# ...              ...
# 52527        2170983
# 52528        2172263
# 52529        2172717
# 52530        2173239
# 52531        2173238
#
# [52532 rows x 9 columns]

# %% [markdown]
# # Can you see which senator declared the most expenses?

# %%
quantity_of_expensive = pd.DataFrame(columns=['SENADOR', 'QUANTIDADE_GASTOS'])
for senator in dataset['SENADOR'].unique():
    quantity_of_expensive = pd.concat(
        [quantity_of_expensive, pd.DataFrame.from_records([{'SENADOR': senator, 'QUANTIDADE_GASTOS': len(dataset[dataset['SENADOR'] == senator])}])]
    )
quantity_of_expensive
# Out:
#                           SENADOR QUANTIDADE_GASTOS
# 0                    ACIR GURGACZ               557
# 0                     AÉCIO NEVES                15
# 0               ALESSANDRO VIEIRA               703
# 0          ALOYSIO NUNES FERREIRA                22
# 0                     ALVARO DIAS               106
# ..                            ...               ...
# 0                     JOSÉ ANÍBAL                89
# 0   MARIA ELIZA DE AGUIAR E SILVA                26
# 0                    NAILDE PANTA                 1
# 0                    NILDA GONDIM               155
# 0            VIRGINIO DE CARVALHO                 3
#
# [139 rows x 2 columns]

# %%
# Creating the chart
trace = go.Scatter(
    x = quantity_of_expensive['SENADOR'],
    y = quantity_of_expensive['QUANTIDADE_GASTOS'],
    mode = 'markers',
    marker={
        'color':'#e74c3c',
        'line':{
            'width':1,
            'color':'#c0392b'
        }
    },
    opacity=.8
)
# Storing chart in a list
data = [trace]
# Creating Layout
layout = go.Layout(
    title='Quantidade de gastos declarados por Senador',
    yaxis={'title':'Quantidade de gastos'},
    xaxis={'title':'Nome Senador'}
)
# Creating the figure that will be displayed
fig = go.Figure(data=data, layout=layout)
# Showing figure/graph
py.iplot(fig)
# Out:
# <div>                            <div id="c6d7c231-a8d1-4728-a3ef-d162b6b1d3aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6d7c231-a8d1-4728-a3ef-d162b6b1d3aa")) {                    Plotly.newPlot(                        "c6d7c231-a8d1-4728-a3ef-d162b6b1d3aa",                        [{"marker":{"color":"#e74c3c","line":{"color":"#c0392b","width":1}},"mode":"markers","opacity":0.8,"x":["ACIR GURGACZ","A\u00c9CIO NEVES","ALESSANDRO VIEIRA","ALOYSIO NUNES FERREIRA","ALVARO DIAS","ANA AM\u00c9LIA","\u00c2NGELA PORTELA","ANGELO CORONEL","ANTONIO ANASTASIA","ANT\u00d4NIO CARLOS VALADARES","ARMANDO MONTEIRO","AROLDE DE OLIVEIRA","ATA\u00cdDES OLIVEIRA","BENEDITO DE LIRA","BLAIRO MAGGI","CARLOS VIANA","C\u00c1SSIO CUNHA LIMA","CHICO RODRIGUES","CID GOMES","CIRO NOGUEIRA","CONF\u00daCIO MOURA","DALIRIO BEBER","DANIELLA RIBEIRO","D\u00c1RIO BERGER","DAVI ALCOLUMBRE","EDISON LOB\u00c3O","EDUARDO AMORIM","EDUARDO BRAGA","EDUARDO GIR\u00c3O","EDUARDO GOMES","ELIZIANE GAMA","ELMANO F\u00c9RRER","ESPERIDI\u00c3O AMIN","FABIANO CONTARATO","FERNANDO BEZERRA COELHO","FERNANDO COLLOR","FL\u00c1VIO ARNS","FL\u00c1VIO BOLSONARO","FLEXA RIBEIRO","GARIBALDI ALVES FILHO","GLEISI HOFFMANN","GUARACY SILVEIRA","H\u00c9LIO JOS\u00c9","HUMBERTO COSTA","IRAJ\u00c1","IVO CASSOL","IZALCI LUCAS","JADER BARBALHO","JAQUES WAGNER","JARBAS VASCONCELOS","JAYME CAMPOS","JEAN PAUL PRATES","JO\u00c3O ALBERTO SOUZA","JO\u00c3O CAPIBERIBE","JORGE VIANA","JORGINHO MELLO","JOS\u00c9 AGRIPINO","JOS\u00c9 MARANH\u00c3O","JOS\u00c9 MEDEIROS","JOS\u00c9 PIMENTEL","JOS\u00c9 SERRA","JU\u00cdZA SELMA","K\u00c1TIA ABREU","LASIER MARTINS","L\u00cdDICE DA MATA","LINDBERGH FARIAS","LUCAS BARRETO","L\u00daCIA V\u00c2NIA","LUIS CARLOS HEINZE","LUIZ CARLOS DO CARMO","LUIZ PASTORE","MAGNO MALTA","MAILZA GOMES","MAJOR OLIMPIO","MARA GABRILLI","MARCELO CASTRO","MARCIO BITTAR","MARCOS DO VAL","MARCOS ROG\u00c9RIO","MARIA DO CARMO ALVES","MARTA SUPLICY","MECIAS DE JESUS","NELSINHO TRAD","OMAR AZIZ","ORIOVISTO GUIMAR\u00c3ES","OTTO ALENCAR","PAULO ALBUQUERQUE","PAULO BAUER","PAULO PAIM","PAULO ROCHA","PEDRO CHAVES DOS SANTOS FILHO","PL\u00cdNIO VAL\u00c9RIO","PRISCO BEZERRA","RAIMUNDO LIRA","RANDOLFE RODRIGUES","RENAN CALHEIROS","RENILDE BULH\u00d5ES","RICARDO FERRA\u00c7O","ROBERTO REQUI\u00c3O","ROBERTO ROCHA","RODRIGO CUNHA","RODRIGO PACHECO","ROG\u00c9RIO CARVALHO","ROM\u00c1RIO","ROMERO JUC\u00c1","ROSE DE FREITAS","S\u00c9RGIO PETEC\u00c3O","SIMONE TEBET","SIQUEIRA CAMPOS","SORAYA THRONICKE","STYVENSON VALENTIM","TASSO JEREISSATI","TELM\u00c1RIO MOTA","VALDIR RAUPP","VANDERLAN CARDOSO","VANESSA GRAZZIOTIN","VENEZIANO VITAL DO R\u00caGO","VICENTINHO ALVES","WALDEMIR MOKA","WALTER PINHEIRO","WELLINGTON FAGUNDES","WEVERTON ROCHA","WILDER MORAIS","Z\u00c9 SANTANA","ZENAIDE MAIA","ZEQUINHA MARINHO","ZEZ\u00c9 PERRELLA","CARLOS F\u00c1VARO","CARLOS PORTINHO","DIEGO TAVARES","NEY SUASSUNA","CHIQUINHO FEITOSA","ELIANE NOGUEIRA","GIORDANO","JOS\u00c9 AN\u00cdBAL","MARIA ELIZA DE AGUIAR E SILVA","NAILDE PANTA","NILDA GONDIM","VIRGINIO DE CARVALHO"],"y":[557,15,703,22,106,33,5,274,1003,9,24,316,8,8,6,1739,13,394,439,458,983,13,714,790,206,2,14,278,26,668,332,939,1017,908,1008,126,902,468,17,14,46,28,3,1351,353,8,127,63,1547,924,403,936,3,9,47,996,12,342,15,14,1013,452,407,610,71,7,685,30,1338,266,28,4,658,1123,936,590,303,511,862,299,16,368,374,177,68,390,73,27,1449,848,13,383,40,12,532,513,23,19,28,553,637,792,898,488,19,446,299,634,4,781,166,82,1253,6,187,7,730,1,8,19,1689,771,16,11,673,1391,10,637,283,74,15,18,71,259,89,26,1,155,3],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"er ...

# %% [markdown]
# ## Generating a box plot for the 4 senators who spent the most

# %%
# Generating graphs for senator 1
trace1 = go.Box(
    y = dataset.loc[dataset['SENADOR'] == 'CARLOS VIANA', 'VALOR_REEMBOLSADO'],
    name = 'CARLOS VIANA',
    marker = {'color': '#f39c12'}
)
# Generating graphs for senator 2
trace2 = go.Box(
    y = dataset.loc[dataset['SENADOR'] == 'WELLINGTON FAGUNDES', 'VALOR_REEMBOLSADO'],
    name = 'WELLINGTON FAGUNDES',
    marker = {'color': '#e67e22'}
)
# Generating graphs for senator 3
trace3 = go.Box(
    y = dataset.loc[dataset['SENADOR'] == 'JAQUES WAGNER', 'VALOR_REEMBOLSADO'],
    name = 'JAQUES WAGNER',
    marker = {'color': '#d35400'}
)
# Generating graphs for senator 4
trace4 = go.Box(
    y = dataset.loc[dataset['SENADOR'] == 'PAULO PAIM', 'VALOR_REEMBOLSADO'],
    name = 'PAULO PAIM',
    marker = {'color': '#e74c3c'}
)
data = [trace1, trace2, trace3, trace4]
layout = go.Layout(
    title = 'Dispersão de valores reembolsado para 4 senadores que mais reembolsaram',
    titlefont = {'family': 'Arial', 'size': 22, 'color': '#7f7f7f'},
    xaxis = {'title': 'Senadores'},
    yaxis = {'title': 'Valor de reembolso'},
    paper_bgcolor = 'rgb(243, 243, 243)',
    plot_bgcolor = 'rgb(243, 243, 243)'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div>                            <div id="1968e9f2-7a42-4d84-92e6-8dd5bdd3a5b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1968e9f2-7a42-4d84-92e6-8dd5bdd3a5b6")) {                    Plotly.newPlot(                        "1968e9f2-7a42-4d84-92e6-8dd5bdd3a5b6",                        [{"marker":{"color":"#f39c12"},"name":"CARLOS VIANA","y":[1392.89,375.88,257.5,6700.0,252.95,72.1,190.19,50.0,600.0,184.94,33.25,30.45,32.6,32.6,36.9,3095.0,369.22,438.39,439.05,547.24,407.39,441.05,451.84,452.5,713.18,626.71,302.78,1380.89,375.8,6700.0,22.0,22.0,53.32,54.44,30.88,63.07,87.6,73.66,868.0,390.0,238.68,250.46,77.0,211.51,40.0,120.0,120.0,120.0,40.0,50.0,20.0,236.1,131.21,30.45,32.6,33.66,30.45,30.54,28.39,123.89,179.0,2618.98,373.39,671.04,684.88,1045.04,275.05,397.05,430.39,323.39,397.05,546.0,737.9,80.3,1390.38,375.8,500.0,6700.0,11.0,22.0,11.0,11.0,46.37,35.45,14.9,33.1,977.0,220.0,127.67,274.04,50.0,180.0,238.75,47.0,403.0,30.0,45.0,201.55,116.21,269.3,303.15,235.8,77.13,0.06,40.0,265.87,32.59,28.39,42.5,8.4,730.0,1227.65,591.76,592.42,790.44,1026.88,209.89,333.44,420.74,443.7,790.16,926.42,360.91,440.65,1400.18,375.8,6700.0,22.0,58.24,23.95,17.89,5.99,14.9,25.8,977.0,5000.0,2000.0,129.64,254.63,240.8,26.35,210.0,210.0,44.0,125.25,26.0,26.0,179.25,46.2,210.0,217.8,217.8,35.0,22.75,59.0,255.41,240.1,240.58,39.72,298.56,50.0,14.5,30.45,30.45,26.34,28.39,239.0,1227.65,2182.5,70.42,1542.39,1542.39,321.77,680.0,631.16,1259.26,825.14,480.79,704.14,735.94,808.92,714.14,741.08,957.48,1283.6,1106.06,761.87,429.93,1401.76,785.43,375.8,6700.0,55.57,78.97,29.8,29.8,977.0,14.0,40.0,146.91,163.87,151.06,89.7,200.0,194.22,84.2,127.0,120.0,25.0,191.69,97.05,180.0,180.0,250.0,235.0,41.8,36.1,158.0,14.8,110.0,200.0,136.99,200.02,150.56,136.11,50.0,185.11,100.71,131.0,28.39,30.45,28.39,28.39,146.05,49.87,96.47,16.1,52.24,49.87,8.08,11.04,5.0,5.6,6.02,5.0,5.3,6.77,7.1,184.0,436.5,558.98,2619.0,615.76,422.39,753.38,1375.58,1106.74,742.18,742.84,211.49,635.69,42.5,43.9,199.59,190.59,190.59,384.39,408.39,408.39,408.39,1687.98,347.59,686.62,429.93,1434.92,375.8,22.2,6000.0,25.47,169.8,977.0,610.0,114.0,112.0,117.0,20.0,200.0,202.5,25.0,264.35,200.77,14.8,259.25,138.0,162.95,108.97,134.76,62.0,177.69,160.52,219.86,200.0,123.0,28.39,28.39,195.64,167.01,144.01,46.6,210.0,210.0,210.0,239.0,5.23,5.74,2182.5,180.0,1216.31,153.59,211.39,246.98,246.98,246.98,264.98,941.78,747.29,400.29,359.0,588.22,550.28,1390.38,375.8,6000.0,60.15,19.9,87.48,977.0,5000.0,2500.0,206.06,723.72,29.95,5.0,157.5,81.42,318.5,216.82,85.0,140.0,30.1,36.04,245.03,61.0,64.5,666.39,187.08,250.26,217.3,221.81,211.22,210.0,423.45,436.5,2619.0,384.39,436.59,1243.08,194.58,232.58,321.57,344.59,393.54,393.57,400.08,455.55,416.57,242.59,248.57,248.57,248.57,248.57,249.59,249.59,249.59,249.59,249.59,286.57,382.57,449.57,164.0,287.59,378.37,677.25,436.43,1385.32,375.8,6000.0,23.56,44.91,89.92,36.88,14.9,1600.0,868.44,2500.0,1500.0,22.53,5.0,200.0,62.2,66.0,215.0,300.0,903.4,240.0,242.04,115.0,981.68,1565.98,268.88,190.58,158.06,188.32,31.41,31.57,62.01,69.8,29.35,46.6,44.7,241.0,12.46,12.49,4.07,36.03,6.46,12.89,27.22,2182.5,47.3,54.97,406.62,755.38,993.69,342.04,466.75,431.9,1388.16,375.8,6000.0,43.9,104.71,90.9,198.56,14.9,14.9,1600.0,977.0,2500.0,24.0,70.0,216.1,264.52,49.11,43.5,235.71,40.8,207.05,31.57,29.35,63.14,32.66,29.35,31.57,43.1,17.1,49.87,50.56,102.8,187.95,436.5,1484.1,1219.58,1379.65,28.0,840.02,468.23,1440.84,383.32,6000.0,26.37,17.9,14.9,14.9,23.96,1600.0,977.0,2500.0,45.0,27.9,119.32,230.0,120.7,170.0,50.0,81.0,81.0,45.9,120.3,160.61,160.61,160.61,6.0,76.0,264.71,212.23,162.06,167.23,163.46,200.94,227.98,213.25,210.91,75.0,32.66,32.66,50.56,315.0,68.8,39.03,2520.26,106.58,550.59,502.0,640.0,53.0,800.0,1174.73,656.59,446.43,1429.89,6000. ...

# %% [markdown]
# # What percentage of the quota did the senators spend?

# %%
average_annual_quota = 483073.99

total_refund_per_year = pd.DataFrame(columns=['SENADOR', 'ANO', 'TOTAL_REEMBOLSO'])
for senator in dataset['SENADOR'].unique():
    df_aux = dataset.loc[dataset['SENADOR'] == senator]
    for year in dataset['ANO'].unique():
        total_refund_per_year = pd.concat(
            [total_refund_per_year, pd.DataFrame.from_records([{'SENADOR': senator, 'ANO': year, 'TOTAL_REEMBOLSO': df_aux.loc[dataset['ANO'] == year, 'VALOR_REEMBOLSADO'].sum()}])]
        )
total_refund_per_year
# Out:
#                  SENADOR   ANO TOTAL_REEMBOLSO
# 0           ACIR GURGACZ  2019       251714.02
# 0           ACIR GURGACZ  2020       415364.91
# 0           ACIR GURGACZ  2021        415374.0
# 0            AÉCIO NEVES  2019        19739.01
# 0            AÉCIO NEVES  2020             0.0
# ..                   ...   ...             ...
# 0           NILDA GONDIM  2020             0.0
# 0           NILDA GONDIM  2021       206458.96
# 0   VIRGINIO DE CARVALHO  2019             0.0
# 0   VIRGINIO DE CARVALHO  2020             0.0
# 0   VIRGINIO DE CARVALHO  2021         5720.56
#
# [417 rows x 3 columns]

# %%
trace1 = go.Bar(
    x = total_refund_per_year['SENADOR'].unique(),
    y = total_refund_per_year.loc[total_refund_per_year['ANO'] == 2019, 'TOTAL_REEMBOLSO'],
    name = 'Ano 2019',
    marker = {'color': '#feca57'}
)
trace2 = go.Bar(
    x = total_refund_per_year['SENADOR'].unique(),
    y = total_refund_per_year.loc[total_refund_per_year['ANO'] == 2020, 'TOTAL_REEMBOLSO'],
    name = 'Ano 2020',
    marker = {'color': '#ff9f43'}
)
trace3 = go.Bar(
    x = total_refund_per_year['SENADOR'].unique(),
    y = total_refund_per_year.loc[total_refund_per_year['ANO'] == 2021, 'TOTAL_REEMBOLSO'],
    name = 'Ano 2021',
    # marker = {'color': '#fjkf13'}
)
quota_array = np.arange(len(total_refund_per_year['SENADOR']))
quota_array.fill(average_annual_quota)
trace4 = go.Scatter(
    x = total_refund_per_year['SENADOR'],
    y = quota_array,
    mode = 'lines',
    name = 'Média da cota anual',
    line = {
        'color': '#341f97',
        'dash': 'dot'
    }
)
data = [trace1, trace2, trace3, trace4]
py.iplot(data)
# Out:
# <div>                            <div id="236da0f8-9e31-4001-b4dc-a7632c08ab74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("236da0f8-9e31-4001-b4dc-a7632c08ab74")) {                    Plotly.newPlot(                        "236da0f8-9e31-4001-b4dc-a7632c08ab74",                        [{"marker":{"color":"#feca57"},"name":"Ano 2019","x":["ACIR GURGACZ","A\u00c9CIO NEVES","ALESSANDRO VIEIRA","ALOYSIO NUNES FERREIRA","ALVARO DIAS","ANA AM\u00c9LIA","\u00c2NGELA PORTELA","ANGELO CORONEL","ANTONIO ANASTASIA","ANT\u00d4NIO CARLOS VALADARES","ARMANDO MONTEIRO","AROLDE DE OLIVEIRA","ATA\u00cdDES OLIVEIRA","BENEDITO DE LIRA","BLAIRO MAGGI","CARLOS VIANA","C\u00c1SSIO CUNHA LIMA","CHICO RODRIGUES","CID GOMES","CIRO NOGUEIRA","CONF\u00daCIO MOURA","DALIRIO BEBER","DANIELLA RIBEIRO","D\u00c1RIO BERGER","DAVI ALCOLUMBRE","EDISON LOB\u00c3O","EDUARDO AMORIM","EDUARDO BRAGA","EDUARDO GIR\u00c3O","EDUARDO GOMES","ELIZIANE GAMA","ELMANO F\u00c9RRER","ESPERIDI\u00c3O AMIN","FABIANO CONTARATO","FERNANDO BEZERRA COELHO","FERNANDO COLLOR","FL\u00c1VIO ARNS","FL\u00c1VIO BOLSONARO","FLEXA RIBEIRO","GARIBALDI ALVES FILHO","GLEISI HOFFMANN","GUARACY SILVEIRA","H\u00c9LIO JOS\u00c9","HUMBERTO COSTA","IRAJ\u00c1","IVO CASSOL","IZALCI LUCAS","JADER BARBALHO","JAQUES WAGNER","JARBAS VASCONCELOS","JAYME CAMPOS","JEAN PAUL PRATES","JO\u00c3O ALBERTO SOUZA","JO\u00c3O CAPIBERIBE","JORGE VIANA","JORGINHO MELLO","JOS\u00c9 AGRIPINO","JOS\u00c9 MARANH\u00c3O","JOS\u00c9 MEDEIROS","JOS\u00c9 PIMENTEL","JOS\u00c9 SERRA","JU\u00cdZA SELMA","K\u00c1TIA ABREU","LASIER MARTINS","L\u00cdDICE DA MATA","LINDBERGH FARIAS","LUCAS BARRETO","L\u00daCIA V\u00c2NIA","LUIS CARLOS HEINZE","LUIZ CARLOS DO CARMO","LUIZ PASTORE","MAGNO MALTA","MAILZA GOMES","MAJOR OLIMPIO","MARA GABRILLI","MARCELO CASTRO","MARCIO BITTAR","MARCOS DO VAL","MARCOS ROG\u00c9RIO","MARIA DO CARMO ALVES","MARTA SUPLICY","MECIAS DE JESUS","NELSINHO TRAD","OMAR AZIZ","ORIOVISTO GUIMAR\u00c3ES","OTTO ALENCAR","PAULO ALBUQUERQUE","PAULO BAUER","PAULO PAIM","PAULO ROCHA","PEDRO CHAVES DOS SANTOS FILHO","PL\u00cdNIO VAL\u00c9RIO","PRISCO BEZERRA","RAIMUNDO LIRA","RANDOLFE RODRIGUES","RENAN CALHEIROS","RENILDE BULH\u00d5ES","RICARDO FERRA\u00c7O","ROBERTO REQUI\u00c3O","ROBERTO ROCHA","RODRIGO CUNHA","RODRIGO PACHECO","ROG\u00c9RIO CARVALHO","ROM\u00c1RIO","ROMERO JUC\u00c1","ROSE DE FREITAS","S\u00c9RGIO PETEC\u00c3O","SIMONE TEBET","SIQUEIRA CAMPOS","SORAYA THRONICKE","STYVENSON VALENTIM","TASSO JEREISSATI","TELM\u00c1RIO MOTA","VALDIR RAUPP","VANDERLAN CARDOSO","VANESSA GRAZZIOTIN","VENEZIANO VITAL DO R\u00caGO","VICENTINHO ALVES","WALDEMIR MOKA","WALTER PINHEIRO","WELLINGTON FAGUNDES","WEVERTON ROCHA","WILDER MORAIS","Z\u00c9 SANTANA","ZENAIDE MAIA","ZEQUINHA MARINHO","ZEZ\u00c9 PERRELLA","CARLOS F\u00c1VARO","CARLOS PORTINHO","DIEGO TAVARES","NEY SUASSUNA","CHIQUINHO FEITOSA","ELIANE NOGUEIRA","GIORDANO","JOS\u00c9 AN\u00cdBAL","MARIA ELIZA DE AGUIAR E SILVA","NAILDE PANTA","NILDA GONDIM","VIRGINIO DE CARVALHO"],"y":[251714.02000000002,19739.010000000002,448395.92000000004,18450.050000000003,105354.32999999999,16596.83,39411.850000000006,339038.63,305573.81,41844.450000000004,34974.54,329547.92000000004,24621.579999999998,8508.779999999999,8543.95,285508.12,12032.509999999998,421313.67999999993,163960.35,452115.70999999996,183431.17,14635.330000000002,295183.45999999996,263372.58999999997,129238.22,37396.6,12810.460000000001,519561.65,20564.550000000003,212399.08000000002,411292.61,420936.07999999996,361520.80000000005,65246.909999999996,402681.1,274505.69,212065.02999999997,180135.58,33263.42,10668.929999999998,28134.75,25215.2,20850.0,414626.70999999996,277345.47,34016.2,231480.66999999998,337083.23000000004,388340.69999999995,398771.75,212059.18,428313.790000000 ...
